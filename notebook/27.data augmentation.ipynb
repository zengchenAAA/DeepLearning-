# %% [markdown]
# ## data augmentation
# * Flip
# * Rotate
# * Random Move&Crop
# * GAN

# %% [markdown]
# ## Flip

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Rotate

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Scale

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Crop Part（裁剪）

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Noise
